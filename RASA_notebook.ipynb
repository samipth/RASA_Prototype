# %%
# !pip install rasa==3.4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rasa==3.4
#   Downloading rasa-3.4.0-py3-none-any.whl (821 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.8/821.8 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: CacheControl<0.13.0,>=0.12.9 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (0.12.11)
# Collecting PyJWT[crypto]<3.0.0,>=2.0.0 (from rasa==3.4)
#   Downloading PyJWT-2.7.0-py3-none-any.whl (22 kB)
# Collecting SQLAlchemy<1.5.0,>=1.4.0 (from rasa==3.4)
#   Downloading SQLAlchemy-1.4.48-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.4 MB/s eta 0:00:00
# Collecting absl-py<1.4,>=0.9 (from rasa==3.4)
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 14.9 MB/s eta 0:00:00
# Collecting aio-pika<9.0.0,>=6.7.1 (from rasa==3.4)
#   Downloading aio_pika-8.3.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 5.7 MB/s eta 0:00:00
# Collecting aiogram<2.24 (from rasa==3.4)
#   Downloading aiogram-2.23.1-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 kB 17.7 MB/s eta 0:00:00
# Collecting aiohttp!=3.7.4.post0,<3.9,>=3.6 (from rasa==3.4)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.6 MB/s eta 0:00:00
# Collecting apscheduler<3.10,>=3.6 (from rasa==3.4)
#   Downloading APScheduler-3.9.1.post1-py2.py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 5.2 MB/s eta 0:00:00
# Collecting attrs<22.2,>=19.3 (from rasa==3.4)
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.3 MB/s eta 0:00:00
# Collecting boto3<2.0,>=1.12 (from rasa==3.4)
#   Downloading boto3-1.26.145-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<2.3,>=1.2 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (2.2.1)
# Collecting colorclass<2.3,>=2.2 (from rasa==3.4)
#   Downloading colorclass-2.2.2-py2.py3-none-any.whl (18 kB)
# Collecting coloredlogs<16,>=10 (from rasa==3.4)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.9 MB/s eta 0:00:00
# Collecting colorhash<1.3.0,>=1.0.2 (from rasa==3.4)
#   Downloading colorhash-1.2.1-py3-none-any.whl (5.7 kB)
# Collecting confluent-kafka<2.0.0,>=1.9.2 (from rasa==3.4)
#   Downloading confluent_kafka-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 55.9 MB/s eta 0:00:00
# Collecting dask==2022.10.2 (from rasa==3.4)
#   Downloading dask-2022.10.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 33.3 MB/s eta 0:00:00
# Collecting fbmessenger<6.1.0,>=6.0.0 (from rasa==3.4)
#   Downloading fbmessenger-6.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: google-auth<3 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (2.17.3)
# Requirement already satisfied: joblib<1.3.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (1.2.0)
# Collecting jsonpickle<2.3,>=1.3 (from rasa==3.4)
#   Downloading jsonpickle-2.2.0-py2.py3-none-any.whl (39 kB)
# Requirement already satisfied: jsonschema<4.17,>=3.2 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (4.3.3)
# Collecting matplotlib<3.6,>=3.1 (from rasa==3.4)
#   Downloading matplotlib-3.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 64.0 MB/s eta 0:00:00
# Collecting mattermostwrapper<2.3,>=2.2 (from rasa==3.4)
#   Downloading mattermostwrapper-2.2.tar.gz (2.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting networkx<2.7,>=2.4 (from rasa==3.4)
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 56.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24.0,>=1.19.2 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (1.22.4)
# Collecting packaging<21.0,>=20.0 (from rasa==3.4)
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (1.0.0)
# Collecting prompt-toolkit<3.0.29,>=3.0 (from rasa==3.4)
#   Downloading prompt_toolkit-3.0.28-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.2/380.2 kB 36.4 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2 (from rasa==3.4)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.9 MB/s eta 0:00:00
# Collecting psycopg2-binary<2.10.0,>=2.8.2 (from rasa==3.4)
#   Downloading psycopg2_binary-2.9.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.2 MB/s eta 0:00:00
# Requirement already satisfied: pydot<1.5,>=1.4 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (1.4.2)
# Collecting pykwalify<1.9,>=1.7 (from rasa==3.4)
#   Downloading pykwalify-1.8.0-py2.py3-none-any.whl (24 kB)
# Collecting pymongo[srv,tls]<3.11,>=3.8 (from rasa==3.4)
#   Downloading pymongo-3.10.1.tar.gz (715 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.9/715.9 kB 43.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil<2.9,>=2.8 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (2.8.2)
# Collecting python-engineio!=5.0.0,<6,>=4 (from rasa==3.4)
#   Downloading python_engineio-4.4.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 6.0 MB/s eta 0:00:00
# Collecting python-socketio<6,>=4.4 (from rasa==3.4)
#   Downloading python_socketio-5.8.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz<2023.0,>=2019.1 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (2022.7.1)
# Collecting questionary<1.11.0,>=1.5.1 (from rasa==3.4)
#   Downloading questionary-1.10.0-py3-none-any.whl (31 kB)
# Collecting randomname<0.2.0,>=0.1.5 (from rasa==3.4)
#   Downloading randomname-0.1.5.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Collecting rasa-sdk<3.5.0,>=3.4.0 (from rasa==3.4)
#   Downloading rasa_sdk-3.4.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 4.7 MB/s eta 0:00:00
# Collecting redis<5.0,>=3.4 (from rasa==3.4)
#   Downloading redis-4.5.5-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: regex<2022.11,>=2020.6 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (2022.10.31)
# Requirement already satisfied: requests<3.0,>=2.23 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (2.27.1)
# Collecting rocketchat_API<1.29.0,>=0.6.31 (from rasa==3.4)
#   Downloading rocketchat_API-1.28.1-py3-none-any.whl (20 kB)
# Collecting ruamel.yaml<0.18.0,>=0.16.5 (from rasa==3.4)
#   Downloading ruamel.yaml-0.17.31-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.1/112.1 kB 11.3 MB/s eta 0:00:00
# Collecting sanic<21.13,>=21.12 (from rasa==3.4)
#   Downloading sanic-21.12.2-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 16.5 MB/s eta 0:00:00
# Collecting sanic-cors<2.1.0,>=2.0.0 (from rasa==3.4)
#   Downloading Sanic_Cors-2.0.1-py2.py3-none-any.whl (17 kB)
# Collecting sanic-jwt<2.0.0,>=1.6.0 (from rasa==3.4)
#   Downloading sanic_jwt-1.8.0-py3-none-any.whl (23 kB)
# Collecting sanic-routing<0.8.0,>=0.7.2 (from rasa==3.4)
#   Downloading sanic_routing-0.7.2-py3-none-any.whl (23 kB)
# Collecting scikit-learn<1.2,>=0.22 (from rasa==3.4)
#   Downloading scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 19.3 MB/s eta 0:00:00
# Collecting scipy<1.9.0,>=1.4.1 (from rasa==3.4)
#   Downloading scipy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 12.5 MB/s eta 0:00:00
# Collecting sentry-sdk<1.12.0,>=0.17.0 (from rasa==3.4)
#   Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (67.7.2)
# Collecting sklearn-crfsuite<0.4,>=0.3 (from rasa==3.4)
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Collecting slack-sdk<4.0.0,>=3.19.2 (from rasa==3.4)
#   Downloading slack_sdk-3.21.3-py2.py3-none-any.whl (276 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.5/276.5 kB 22.2 MB/s eta 0:00:00
# Collecting tarsafe<0.0.4,>=0.0.3 (from rasa==3.4)
#   Downloading tarsafe-0.0.3-py3-none-any.whl (5.0 kB)
# Collecting tensorflow<2.9.0,>=2.8.4 (from rasa==3.4)
#   Downloading tensorflow-2.8.4-cp310-cp310-manylinux2010_x86_64.whl (498.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 1.2 MB/s eta 0:00:00
# Collecting tensorflow-addons<0.18.0,>=0.17.0 (from rasa==3.4)
#   Downloading tensorflow_addons-0.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.4 MB/s eta 0:00:00
# Collecting tensorflow-text<2.9.0,>=2.8.0 (from rasa==3.4)
#   Downloading tensorflow_text-2.8.2-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 82.2 MB/s eta 0:00:00
# Collecting tensorflow_hub<0.13.0,>=0.12.0 (from rasa==3.4)
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 9.1 MB/s eta 0:00:00
# Collecting terminaltables<3.2.0,>=3.1.0 (from rasa==3.4)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm<5.0,>=4.31 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (4.65.0)
# Collecting twilio<7.15,>=6.26 (from rasa==3.4)
#   Downloading twilio-7.14.2-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 69.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from rasa==3.4) (4.5.0)
# Collecting typing-utils<0.2.0,>=0.1.0 (from rasa==3.4)
#   Downloading typing_utils-0.1.0-py3-none-any.whl (10 kB)
# Collecting ujson<6.0,>=1.35 (from rasa==3.4)
#   Downloading ujson-5.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.9 MB/s eta 0:00:00
# Collecting webexteamssdk<1.7.0,>=1.1.1 (from rasa==3.4)
#   Downloading webexteamssdk-1.6.1-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.5/113.5 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4) (8.1.3)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4) (2023.4.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4) (1.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from dask==2022.10.2->rasa==3.4) (0.12.0)
# Collecting aiormq~=6.6.3 (from aio-pika<9.0.0,>=6.7.1->rasa==3.4)
#   Downloading aiormq-6.6.4-py3-none-any.whl (30 kB)
# Collecting yarl (from aio-pika<9.0.0,>=6.7.1->rasa==3.4)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.4 MB/s eta 0:00:00
# Collecting Babel<2.10.0,>=2.9.1 (from aiogram<2.24->rasa==3.4)
#   Downloading Babel-2.9.1-py2.py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 56.3 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from aiogram<2.24->rasa==3.4) (2022.12.7)
# Collecting magic-filter>=1.0.9 (from aiogram<2.24->rasa==3.4)
#   Downloading magic_filter-1.0.9-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.6 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 14.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from apscheduler<3.10,>=3.6->rasa==3.4) (1.16.0)
# Requirement already satisfied: tzlocal!=3.*,>=2.0 in /usr/local/lib/python3.10/dist-packages (from apscheduler<3.10,>=3.6->rasa==3.4) (4.3)
# Collecting botocore<1.30.0,>=1.29.145 (from boto3<2.0,>=1.12->rasa==3.4)
#   Downloading botocore-1.29.145-py3-none-any.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 101.7 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0,>=1.12->rasa==3.4)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3<2.0,>=1.12->rasa==3.4)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from CacheControl<0.13.0,>=0.12.9->rasa==3.4) (1.0.5)
# Collecting humanfriendly>=9.1 (from coloredlogs<16,>=10->rasa==3.4)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa==3.4) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa==3.4) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3->rasa==3.4) (4.9)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema<4.17,>=3.2->rasa==3.4) (0.19.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.6,>=3.1->rasa==3.4) (3.0.9)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.0.29,>=3.0->rasa==3.4) (0.2.6)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from PyJWT[crypto]<3.0.0,>=2.0.0->rasa==3.4) (40.0.2)
# Collecting docopt>=0.6.2 (from pykwalify<1.9,>=1.7->rasa==3.4)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dnspython<2.0.0,>=1.16.0 (from pymongo[srv,tls]<3.11,>=3.8->rasa==3.4)
#   Downloading dnspython-1.16.0-py2.py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.4/188.4 kB 19.5 MB/s eta 0:00:00
# Collecting bidict>=0.21.0 (from python-socketio<6,>=4.4->rasa==3.4)
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Collecting fire (from randomname<0.2.0,>=0.1.5->rasa==3.4)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.23->rasa==3.4) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.23->rasa==3.4) (3.4)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml<0.18.0,>=0.16.5->rasa==3.4)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 38.4 MB/s eta 0:00:00
# Collecting httptools>=0.0.10 (from sanic<21.13,>=21.12->rasa==3.4)
#   Downloading httptools-0.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (414 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.1/414.1 kB 35.1 MB/s eta 0:00:00
# Collecting aiofiles>=0.6.0 (from sanic<21.13,>=21.12->rasa==3.4)
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Collecting websockets>=10.0 (from sanic<21.13,>=21.12->rasa==3.4)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.0 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5 (from aiohttp!=3.7.4.post0,<3.9,>=3.6->rasa==3.4)
#   Downloading multidict-5.2.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 18.5 MB/s eta 0:00:00
# Collecting uvloop>=0.5.3 (from sanic<21.13,>=21.12->rasa==3.4)
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 94.0 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.2,>=0.22->rasa==3.4) (3.1.0)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite<0.4,>=0.3->rasa==3.4)
#   Downloading python_crfsuite-0.9.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (993 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.5/993.5 kB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sklearn-crfsuite<0.4,>=0.3->rasa==3.4) (0.8.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<1.5.0,>=1.4.0->rasa==3.4) (2.0.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (23.3.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (3.8.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow<2.9.0,>=2.8.4->rasa==3.4)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (2.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (1.14.1)
# Collecting tensorboard<2.9,>=2.8 (from tensorflow<2.9.0,>=2.8.4->rasa==3.4)
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 100.0 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.9,>=2.8 (from tensorflow<2.9.0,>=2.8.4->rasa==3.4)
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 38.8 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0 (from tensorflow<2.9.0,>=2.8.4->rasa==3.4)
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 67.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (0.32.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.9.0,>=2.8.4->rasa==3.4) (1.54.0)
# Collecting typeguard>=2.7 (from tensorflow-addons<0.18.0,>=0.17.0->rasa==3.4)
#   Downloading typeguard-4.0.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from webexteamssdk<1.7.0,>=1.1.1->rasa==3.4) (0.18.3)
# Collecting requests-toolbelt (from webexteamssdk<1.7.0,>=1.1.1->rasa==3.4)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.4 MB/s eta 0:00:00
# Collecting pamqp==3.2.1 (from aiormq~=6.6.3->aio-pika<9.0.0,>=6.7.1->rasa==3.4)
#   Downloading pamqp-3.2.1-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.9.0,>=2.8.4->rasa==3.4) (0.40.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.4.0->PyJWT[crypto]<3.0.0,>=2.0.0->rasa==3.4) (1.15.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=0.3.10->dask==2022.10.2->rasa==3.4) (1.0.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3->rasa==3.4) (0.5.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4) (3.4.3)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 67.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4) (2.3.0)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.10/dist-packages (from tzlocal!=3.*,>=2.0->apscheduler<3.10,>=3.6->rasa==3.4) (0.1.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.4.0->PyJWT[crypto]<3.0.0,>=2.0.0->rasa==3.4) (2.21)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=0.11.15->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4) (2.1.2)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from pytz-deprecation-shim->tzlocal!=3.*,>=2.0->apscheduler<3.10,>=3.6->rasa==3.4) (2023.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow<2.9.0,>=2.8.4->rasa==3.4) (3.2.2)
# Building wheels for collected packages: mattermostwrapper, randomname, docopt, fire, pymongo
#   Building wheel for mattermostwrapper (setup.py) ... done
#   Created wheel for mattermostwrapper: filename=mattermostwrapper-2.2-py3-none-any.whl size=2448 sha256=94f2c6766bb1b00c516d7b6e17204331f2cad013579e47dba31bb543c0334525
#   Stored in directory: /root/.cache/pip/wheels/b2/dc/02/e3239f0ea0a676085826846d32ef09b10915c0a33c817d2dbb
#   Building wheel for randomname (setup.py) ... done
#   Created wheel for randomname: filename=randomname-0.1.5-py3-none-any.whl size=58808 sha256=25787733ec7370ec6228d3817b8193f9d24009ef563e8314da75a24335d7cee9
#   Stored in directory: /root/.cache/pip/wheels/ee/df/c1/0bdf17c694217f49657ca36fd0239b9a243c34c27a70ff56ef
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=96b4fcef2ab79064dc5ffda332f4c7271dcef396e27317438c83e62dcb5e24ca
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=7c6221f1c5704661a7832efe126f349478405056ee139c779a44f6ca63cc6fbb
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
#   Building wheel for pymongo (setup.py) ... done
#   Created wheel for pymongo: filename=pymongo-3.10.1-cp310-cp310-linux_x86_64.whl size=471674 sha256=3c0446a1e04774eb5a47c5a13a80aa17b4f1262603a53cb1f64fc8da56816ad4
#   Stored in directory: /root/.cache/pip/wheels/29/ff/28/8624f4571ee5e095adb4057078b7bfc1d44d5d0a158d4f24bb
# Successfully built mattermostwrapper randomname docopt fire pymongo
# Installing collected packages: tensorflow-estimator, sanic-routing, python-crfsuite, keras, docopt, confluent-kafka, websockets, uvloop, ujson, typing-utils, typeguard, terminaltables, tensorboard-data-server, tarsafe, SQLAlchemy, slack-sdk, sklearn-crfsuite, sentry-sdk, scipy, ruamel.yaml.clib, python-engineio, pymongo, PyJWT, psycopg2-binary, protobuf, prompt-toolkit, pamqp, packaging, networkx, multidict, magic-filter, keras-preprocessing, jsonpickle, jmespath, humanfriendly, httptools, frozenlist, fire, dnspython, colorhash, colorclass, bidict, Babel, attrs, async-timeout, aiofiles, absl-py, yarl, twilio, tensorflow_hub, tensorflow-addons, scikit-learn, sanic-jwt, sanic, ruamel.yaml, rocketchat_API, requests-toolbelt, redis, randomname, questionary, python-socketio, mattermostwrapper, matplotlib, fbmessenger, dask, coloredlogs, botocore, aiosignal, webexteamssdk, sanic-cors, s3transfer, pykwalify, google-auth-oauthlib, apscheduler, aiormq, aiohttp, tensorboard, rasa-sdk, boto3, aiogram, aio-pika, tensorflow, tensorflow-text, rasa
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.12.0
#     Uninstalling tensorflow-estimator-2.12.0:
#       Successfully uninstalled tensorflow-estimator-2.12.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.12.0
#     Uninstalling keras-2.12.0:
#       Successfully uninstalled keras-2.12.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.0
#     Uninstalling tensorboard-data-server-0.7.0:
#       Successfully uninstalled tensorboard-data-server-0.7.0
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.10
#     Uninstalling SQLAlchemy-2.0.10:
#       Successfully uninstalled SQLAlchemy-2.0.10
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.10.1
#     Uninstalling scipy-1.10.1:
#       Successfully uninstalled scipy-1.10.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.38
#     Uninstalling prompt-toolkit-3.0.38:
#       Successfully uninstalled prompt-toolkit-3.0.38
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.1
#     Uninstalling packaging-23.1:
#       Successfully uninstalled packaging-23.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
#   Attempting uninstall: jsonpickle
#     Found existing installation: jsonpickle 3.0.1
#     Uninstalling jsonpickle-3.0.1:
#       Successfully uninstalled jsonpickle-3.0.1
#   Attempting uninstall: Babel
#     Found existing installation: Babel 2.12.1
#     Uninstalling Babel-2.12.1:
#       Successfully uninstalled Babel-2.12.1
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.4.0
#     Uninstalling absl-py-1.4.0:
#       Successfully uninstalled absl-py-1.4.0
#   Attempting uninstall: tensorflow_hub
#     Found existing installation: tensorflow-hub 0.13.0
#     Uninstalling tensorflow-hub-0.13.0:
#       Successfully uninstalled tensorflow-hub-0.13.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
#   Attempting uninstall: dask
#     Found existing installation: dask 2022.12.1
#     Uninstalling dask-2022.12.1:
#       Successfully uninstalled dask-2022.12.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.12.2
#     Uninstalling tensorboard-2.12.2:
#       Successfully uninstalled tensorboard-2.12.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.12.0
#     Uninstalling tensorflow-2.12.0:
#       Successfully uninstalled tensorflow-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# distributed 2022.12.1 requires dask==2022.12.1, but you have dask 2022.10.2 which is incompatible.
# statsmodels 0.13.5 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# tensorflow-datasets 4.9.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# xarray 2022.12.0 requires packaging>=21.3, but you have packaging 20.9 which is incompatible.
# Successfully installed Babel-2.9.1 PyJWT-2.7.0 SQLAlchemy-1.4.48 absl-py-1.3.0 aio-pika-8.3.0 aiofiles-23.1.0 aiogram-2.23.1 aiohttp-3.8.4 aiormq-6.6.4 aiosignal-1.3.1 apscheduler-3.9.1.post1 async-timeout-4.0.2 attrs-22.1.0 bidict-0.22.1 boto3-1.26.145 botocore-1.29.145 colorclass-2.2.2 coloredlogs-15.0.1 colorhash-1.2.1 confluent-kafka-1.9.2 dask-2022.10.2 dnspython-1.16.0 docopt-0.6.2 fbmessenger-6.0.0 fire-0.5.0 frozenlist-1.3.3 google-auth-oauthlib-0.4.6 httptools-0.5.0 humanfriendly-10.0 jmespath-1.0.1 jsonpickle-2.2.0 keras-2.8.0 keras-preprocessing-1.1.2 magic-filter-1.0.9 matplotlib-3.5.3 mattermostwrapper-2.2 multidict-5.2.0 networkx-2.6.3 packaging-20.9 pamqp-3.2.1 prompt-toolkit-3.0.28 protobuf-3.19.6 psycopg2-binary-2.9.6 pykwalify-1.8.0 pymongo-3.10.1 python-crfsuite-0.9.9 python-engineio-4.4.1 python-socketio-5.8.0 questionary-1.10.0 randomname-0.1.5 rasa-3.4.0 rasa-sdk-3.4.1 redis-4.5.5 requests-toolbelt-1.0.0 rocketchat_API-1.28.1 ruamel.yaml-0.17.31 ruamel.yaml.clib-0.2.7 s3transfer-0.6.1 sanic-21.12.2 sanic-cors-2.0.1 sanic-jwt-1.8.0 sanic-routing-0.7.2 scikit-learn-1.1.3 scipy-1.8.1 sentry-sdk-1.11.1 sklearn-crfsuite-0.3.6 slack-sdk-3.21.3 tarsafe-0.0.3 tensorboard-2.8.0 tensorboard-data-server-0.6.1 tensorflow-2.8.4 tensorflow-addons-0.17.1 tensorflow-estimator-2.8.0 tensorflow-text-2.8.2 tensorflow_hub-0.12.0 terminaltables-3.1.10 twilio-7.14.2 typeguard-4.0.0 typing-utils-0.1.0 ujson-5.7.0 uvloop-0.17.0 webexteamssdk-1.6.1 websockets-11.0.3 yarl-1.9.2

# %%
# !pip install -U ipython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (7.34.0)
# Collecting ipython
#   Downloading ipython-8.13.2-py3-none-any.whl (797 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.7/797.7 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython) (4.4.2)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 49.4 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython) (0.7.5)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 (from ipython)
#   Downloading prompt_toolkit-3.0.38-py3-none-any.whl (385 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.8/385.8 kB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython) (2.14.0)
# Collecting stack-data (from ipython)
#   Downloading stack_data-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.10/dist-packages (from ipython) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.6)
# Collecting executing>=1.2.0 (from stack-data->ipython)
#   Downloading executing-1.2.0-py2.py3-none-any.whl (24 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython)
#   Downloading asttokens-2.2.1-py2.py3-none-any.whl (26 kB)
# Collecting pure-eval (from stack-data->ipython)
#   Downloading pure_eval-0.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Installing collected packages: pure-eval, executing, prompt-toolkit, jedi, asttokens, stack-data, ipython
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.28
#     Uninstalling prompt-toolkit-3.0.28:
#       Successfully uninstalled prompt-toolkit-3.0.28
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.13.2 which is incompatible.
# rasa 3.4.0 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.38 which is incompatible.
# rasa-sdk 3.4.1 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.38 which is incompatible.
# Successfully installed asttokens-2.2.1 executing-1.2.0 ipython-8.13.2 jedi-0.18.2 prompt-toolkit-3.0.38 pure-eval-0.2.2 stack-data-0.6.2

# %%
# !pip install tzlocal==2.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tzlocal==2.1 in /usr/local/lib/python3.10/dist-packages (2.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from tzlocal==2.1) (2022.7.1)

# %%
# !pip install jedi==0.11
# !pip install pluggy==0.6
# !pip install prompt-toolkit==2.0.10
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jedi==0.11
#   Downloading jedi-0.11.0-py2.py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.8/146.8 kB 3.7 MB/s eta 0:00:00
# Collecting parso==0.1.0 (from jedi==0.11)
#   Downloading parso-0.1.0-py2.py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: parso, jedi
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.3
#     Uninstalling parso-0.8.3:
#       Successfully uninstalled parso-0.8.3
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.18.2
#     Uninstalling jedi-0.18.2:
#       Successfully uninstalled jedi-0.18.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 8.13.2 requires jedi>=0.16, but you have jedi 0.11.0 which is incompatible.
# Successfully installed jedi-0.11.0 parso-0.1.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pluggy==0.6
#   Downloading pluggy-0.6.0-py3-none-any.whl (13 kB)
# Installing collected packages: pluggy
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 1.0.0
#     Uninstalling pluggy-1.0.0:
#       Successfully uninstalled pluggy-1.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytest 7.2.2 requires pluggy<2.0,>=0.12, but you have pluggy 0.6.0 which is incompatible.
# rasa 3.4.0 requires pluggy<2.0.0,>=1.0.0, but you have pluggy 0.6.0 which is incompatible.
# rasa 3.4.0 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.38 which is incompatible.
# Successfully installed pluggy-0.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting prompt-toolkit==2.0.10
#   Downloading prompt_toolkit-2.0.10-py3-none-any.whl (340 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.0/340.0 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit==2.0.10) (1.16.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit==2.0.10) (0.2.6)
# Installing collected packages: prompt-toolkit
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.38
#     Uninstalling prompt-toolkit-3.0.38:
#       Successfully uninstalled prompt-toolkit-3.0.38
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 8.13.2 requires jedi>=0.16, but you have jedi 0.11.0 which is incompatible.
# ipython 8.13.2 requires prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30, but you have prompt-toolkit 2.0.10 which is incompatible.
# rasa 3.4.0 requires pluggy<2.0.0,>=1.0.0, but you have pluggy 0.6.0 which is incompatible.
# rasa 3.4.0 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 2.0.10 which is incompatible.
# rasa-sdk 3.4.1 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 2.0.10 which is incompatible.
# Successfully installed prompt-toolkit-2.0.10

# %%
# !pip install -U ipython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (8.13.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython) (4.4.2)
# Collecting jedi>=0.16 (from ipython)
#   Using cached jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython) (0.7.5)
# Collecting prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 (from ipython)
#   Using cached prompt_toolkit-3.0.38-py3-none-any.whl (385 kB)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython) (2.14.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.10/dist-packages (from ipython) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython) (4.8.0)
# Collecting parso<0.9.0,>=0.8.0 (from jedi>=0.16->ipython)
#   Downloading parso-0.8.3-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython) (2.2.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Installing collected packages: prompt-toolkit, parso, jedi
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 2.0.10
#     Uninstalling prompt-toolkit-2.0.10:
#       Successfully uninstalled prompt-toolkit-2.0.10
#   Attempting uninstall: parso
#     Found existing installation: parso 0.1.0
#     Uninstalling parso-0.1.0:
#       Successfully uninstalled parso-0.1.0
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.11.0
#     Uninstalling jedi-0.11.0:
#       Successfully uninstalled jedi-0.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasa 3.4.0 requires pluggy<2.0.0,>=1.0.0, but you have pluggy 0.6.0 which is incompatible.
# rasa 3.4.0 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.38 which is incompatible.
# rasa-sdk 3.4.1 requires prompt-toolkit<3.0.29,>=3.0, but you have prompt-toolkit 3.0.38 which is incompatible.
# Successfully installed jedi-0.18.2 parso-0.8.3 prompt-toolkit-3.0.38

# %%
# !python -m spacy download en_core_web_sm
# Out:
# 2023-06-02 02:03:29.749560: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-06-02 02:03:29.749628: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 40.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (20.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install nest_asyncio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.5.6)

# %%
import os
import rasa
import nest_asyncio

nest_asyncio.apply()

print("event loop is ready")
# Out:
# event loop is ready

# %%
from rasa.cli.scaffold import create_initial_project

project = 'rasa_3x'
create_initial_project(project)

# %%
os.chdir(project)
print(os.listdir("."))
# Out:
# ['endpoints.yml', 'actions', 'tests', 'domain.yml', 'config.yml', 'data', 'credentials.yml']

# %%
config = "config.yml"
training_files = "data/"
domain = "domain.yml"
output = "models/"

print(config, training_files, domain, output)
# Out:
# config.yml data/ domain.yml models/

# %%
model_path = rasa.train(domain, config, [training_files], output)

print(model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/rasa/engine/caching.py:152: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base: DeclarativeMeta = declarative_base()
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# (0lqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqk(B
# (0x(B Rasa Open Source reports anonymous usage telemetry to help improve the product (0x(B
# (0x(B for all its users.                                                             (0x(B
# (0x(B                                                                                (0x(B
# (0x(B If you'd like to opt-out, you can use `rasa telemetry disable`.                (0x(B
# (0x(B To learn more, check out https://rasa.com/docs/rasa/telemetry/telemetry.       (0x(B
# (0mqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqqj(B
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# The configuration for policies and pipeline was chosen automatically. It was written into the config file at 'config.yml'.
# /usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/model_data.py:774: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.concatenate(np.array(f)),
# Epochs: 100%|██████████| 100/100 [00:50<00:00,  1.96it/s, t_loss=1.16, i_acc=1]
# Processed story blocks: 100%|██████████| 3/3 [00:00<00:00, 252.44it/s, # trackers=1]
# Processed story blocks: 100%|██████████| 3/3 [00:00<00:00, 237.19it/s, # trackers=3]
# Processed story blocks: 100%|██████████| 3/3 [00:00<00:00, 92.24it/s, # trackers=12]
# Processed story blocks: 100%|██████████| 3/3 [00:00<00:00, 30.12it/s, # trackers=39]
# Processed rules: 100%|██████████| 2/2 [00:00<00:00, 357.57it/s, # trackers=1]
# Processed trackers: 100%|██████████| 3/3 [00:00<00:00, 117.66it/s, # action=12]
# Processed actions: 12it [00:00, 570.37it/s, # examples=12]
# Processed trackers: 100%|██████████| 2/2 [00:00<00:00, 123.36it/s, # action=5]
# Processed actions: 5it [00:00, 1054.43it/s, # examples=4]
# Processed trackers: 100%|██████████| 3/3 [00:00<00:00, 198.39it/s, # action=12]
# Processed trackers: 100%|██████████| 2/2 [00:00<00:00, 969.11it/s]
# Processed trackers: 100%|██████████| 5/5 [00:00<00:00, 824.06it/s]
# Processed trackers: 100%|██████████| 120/120 [00:00<00:00, 797.14it/s, # action=30]
# /usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/model_data_utils.py:388: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(values), number_of_dimensions=4
# /usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/model_data_utils.py:404: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   MASK: [FeatureArray(np.array(attribute_masks), number_of_dimensions=3)]
# Epochs:   0%|          | 0/100 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_1_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_1_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_1_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Epochs: 100%|██████████| 100/100 [00:25<00:00,  3.94it/s, t_loss=2.42, loss=2.26, acc=1]
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Processed trackers: 100%|██████████| 120/120 [00:00<00:00, 922.85it/s, # intent=12]
# Epochs: 100%|██████████| 100/100 [00:24<00:00,  4.10it/s, t_loss=0.122, loss=0.00953, acc=1]
# /usr/local/lib/python3.10/dist-packages/rasa/core/policies/unexpected_intent_policy.py:839: DeprecationWarning: the `interpolation=` argument to quantile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   quantile_values = np.quantile(  # type: ignore[call-overload]
# Your Rasa model is trained and saved at 'models/20230602-020057-coal-column.tar.gz'.
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# TrainingResult(model='models/20230602-020057-coal-column.tar.gz', code=0, dry_run_results=None)

# %%
from rasa.jupyter import chat

endpoints = None
chat(model_path.model, endpoints)
# Out:
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Your bot is ready to talk! Type your messages here or send '/stop'.
# chup
# Bye
# stop
# Great, carry on!
# /stop

# %%
print("Hello World")
# Out:
# Hello World

# %%
# %%writefile data/nlu.yml
#
# version: "3.1"
#
# nlu:
#
# - intent: check_balance
#   examples: |
#     - What's current balance of [Ram](name)?
#     - How much money do [Shyam](name) have?
#     - Can you tell [hari](name) balance?
#
# - intent: check_transaction_history
#   examples: |
#     - Show my transaction history
#     - What are my recent transactions?
#
# - intent: greet
#   examples: |
#     - hey
#     - hello
#     - hi
#     - hello there
#     - good morning
#     - good evening
#     - moin
#     - hey there
#     - let's go
#     - hey dude
#     - goodmorning
#     - goodevening
#     - good afternoon
#
# - intent: goodbye
#   examples: |
#     - cu
#     - good by
#     - cee you later
#     - good night
#     - bye
#     - goodbye
#     - have a nice day
#     - see you around
#     - bye bye
#     - see you later
#
# - intent: affirm
#   examples: |
#     - yes
#     - y
#     - indeed
#     - of course
#     - that sounds good
#     - correct
#
# - intent: deny
#   examples: |
#     - no
#     - n
#     - never
#     - I don't think so
#     - don't like that
#     - no way
#     - not really
#
# - intent: mood_great
#   examples: |
#     - perfect
#     - great
#     - amazing
#     - feeling like a king
#     - wonderful
#     - I am feeling very good
#     - I am great
#     - I am amazing
#     - I am going to save the world
#     - super stoked
#     - extremely good
#     - so so perfect
#     - so good
#     - so perfect
#
# - intent: mood_unhappy
#   examples: |
#     - my day was horrible
#     - I am sad
#     - I don't feel very well
#     - I am disappointed
#     - super sad
#     - I'm so sad
#     - sad
#     - very sad
#     - unhappy
#     - not good
#     - not very good
#     - extremly sad
#     - so saad
#     - so sad
#
# - intent: bot_challenge
#   examples: |
#     - are you a bot?
#     - are you a human?
#     - am I talking to a bot?
#     - am I talking to a human?
# Out:
# Overwriting data/nlu.yml

# %%
# %%writefile domain.yml
#
# version: "3.1"
#
# intents:
#   - greet
#   - goodbye
#   - affirm
#   - deny
#   - mood_great
#   - mood_unhappy
#   - bot_challenge
#   - check_balance
#   - check_transaction_history
#
# entities:
#   - account_number
#   - name
#   - balance
#
# slots:
#   name:
#     type: text
#     influence_conversation: false
#     mappings:
#       - type: from_entity
#         entity: name
#       - type: from_text
#         intent: inform
#         not_intent: goodbye
#
#
#   account_number:
#     type: text
#     influence_conversation: false
#     mappings:
#       - type: from_entity
#         entity: account_number
#       - type: from_text
#         intent: inform
#         not_intent: goodbye
#
#   balance:
#     type: text
#     influence_conversation: false
#     mappings:
#       - type: from_entity
#         entity: account_number
#       - type: from_text
#         intent: inform
#         not_intent: goodbye
#
# responses:
#
#   utter_check_balance:
#   - text: "Dear {name}, your account {account_number} has a balance of Rs. 1000."
#
#   utter_check_transaction_history:
#     - text: "Here are your recent transactions: ..."
#
#   utter_greet:
#   - text: "Hey! How are you?"
#
#   utter_cheer_up:
#   - text: "Here is something to cheer you up:"
#     image: "https://i.imgur.com/nGF1K8f.jpg"
#
#   utter_did_that_help:
#   - text: "Did that help you?"
#
#   utter_happy:
#   - text: "Great, carry on!"
#
#   utter_goodbye:
#   - text: "Bye"
#
#   utter_iamabot:
#   - text: "I am a bot, powered by Rasa."
#
# session_config:
#   session_expiration_time: 60
#   carry_over_slots_to_new_session: true
# Out:
# Overwriting domain.yml

# %%
# %%writefile actions/actions.py

# This files contains your custom actions which can be used to run
# custom Python code.
#
# See this guide on how to implement these action:
# https://rasa.com/docs/rasa/custom-actions


# This is a simple example for a custom action which utters "Hello World!"

from typing import Any, Text, Dict, List
from rasa_sdk import Action, Tracker
from rasa_sdk.executor import CollectingDispatcher

database = {
    "harry": {
        "account_number": "1234",
        "balance": 1000
    },
    "ron": {
        "account_number": "5678",
        "balance": 2500
    }
}

class ActionCheckBalance(Action):
    def name(self) -> Text:
        return "utter_check_balance"

    def run(self, dispatcher: CollectingDispatcher,
            tracker: Tracker,
            domain: Dict[Text, Any]) -> List[Dict[Text, Any]]:
        name = tracker.get_slot("name")
        
        if name in database:
            account_number = database[name]["account_number"]
            balance = database[name]["balance"]
            dispatcher.utter_message(template="utter_check_balance", name=name, account_number=account_number)
        else:
            dispatcher.utter_message("Sorry, the provided details are incorrect.")

        return []
# Out:
# Overwriting actions/actions.py

# %%
# %%writefile data/stories.yml
#
# version: "3.1"
#
# stories:
#
# - story: happy path
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: mood_great
#   - action: utter_happy
#
# - story: sad path 1
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: mood_unhappy
#   - action: utter_cheer_up
#   - action: utter_did_that_help
#   - intent: affirm
#   - action: utter_happy
#
# - story: sad path 2
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: mood_unhappy
#   - action: utter_cheer_up
#   - action: utter_did_that_help
#   - intent: deny
#   - action: utter_goodbye
#
# - story: Check balance
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: check_balance
#   - action: utter_check_balance
#   - intent: goodbye
#   - action: utter_goodbye
#
#
# - story: Transaction history
#   steps:
#   - intent: greet
#   - action: utter_greet
#   - intent: check_transaction_history
#   - action: utter_check_transaction_history
#   - intent: goodbye
#   - action: utter_goodbye
# Out:
# Overwriting data/stories.yml

# %%
model_path = rasa.train(domain, config, [training_files], output)

print(model_path)
# Out:
# The configuration for policies and pipeline was chosen automatically. It was written into the config file at 'config.yml'.
# Your Rasa model is trained and saved at 'models/20230602-090639-jovial-zinc.tar.gz'.
# <frozen importlib._bootstrap>:283: DeprecationWarning: the load_module() method is deprecated and slated for removal in Python 3.12; use exec_module() instead
# TrainingResult(model='models/20230602-090639-jovial-zinc.tar.gz', code=0, dry_run_results=None)

# %%
endpoints = None
chat(model_path.model, endpoints)
# Out:
# /usr/local/lib/python3.10/dist-packages/rasa/shared/core/slot_mappings.py:221: UserWarning: Slot auto-fill has been removed in 3.0 and replaced with a new explicit mechanism to set slots. Please refer to https://rasa.com/docs/rasa/domain#slots to learn more.
#   rasa.shared.utils.io.raise_warning(
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-72' coro=<load_agent() done, defined at /usr/local/lib/python3.10/dist-packages/rasa/core/agent.py:195> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-61-686a66ff9f12>", line 2, in <module>
#     chat(model_path.model, endpoints)
#   File "/usr/local/lib/python3.10/dist-packages/rasa/jupyter.py", line 33, in chat
#     agent = asyncio.run(
#   File "/usr/local/lib/python3.10/dist-packages/nest_asyncio.py", line 35, in run
#     return loop.run_until_complete(task)
#   File "/usr/local/lib/python3.10/dist-packages/nest_asyncio.py", line 84, in run_until_complete
#     self._run_once()
#   File "/usr/local/lib/python3.10/dist-packages/nest_asyncio.py", line 120, in _run_once
#     handle._run()
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.10/dist-packages/nest_asyncio.py", line 196, in step
#     step_orig(task, exc)
#   File "/usr/lib/python3.10/asyncio/tasks.py", line 232, in __step
#     result = coro.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/rasa/core/agent.py", line 254, in load_agent
#     agent.load_model(model_path)
#   File "/usr/local/lib/python3.10/dist-packages/rasa/core/agent.py", line 352, in load_model
#     self.processor = MessageProcessor(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/core/processor.py", line 96, in __init__
#     self.model_filename, self.model_metadata, self.graph_runner = self._load_model(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/core/processor.py", line 122, in _load_model
#     metadata, runner = loader.load_predict_graph_runner(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/engine/loader.py", line 29, in load_predict_graph_runner
#     runner = graph_runner_class.create(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/engine/runner/dask.py", line 51, in create
#     return cls(graph_schema, model_storage, execution_context, hooks)
#   File "/usr/local/lib/python3.10/dist-packages/rasa/engine/runner/dask.py", line 37, in __init__
#     self._instantiated_nodes: Dict[Text, GraphNode] = self._instantiate_nodes(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/engine/runner/dask.py", line 60, in _instantiate_nodes
#     return {
#   File "/usr/local/lib/python3.10/dist-packages/rasa/engine/runner/dask.py", line 61, in <dictcomp>
#     node_name: GraphNode.from_schema_node(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/engine/graph.py", line 534, in from_schema_node
#     return cls(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/engine/graph.py", line 379, in __init__
#     self._load_component()
#   File "/usr/local/lib/python3.10/dist-packages/rasa/engine/graph.py", line 390, in _load_component
#     self._component: GraphComponent = constructor(  # type: ignore[no-redef]
#   File "/usr/local/lib/python3.10/dist-packages/rasa/nlu/classifiers/diet_classifier.py", line 1111, in load
#     return cls._load(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/nlu/classifiers/diet_classifier.py", line 1142, in _load
#     model = cls._load_model(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/nlu/classifiers/diet_classifier.py", line 1235, in _load_model
#     model = cls._load_model_class(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/nlu/classifiers/diet_classifier.py", line 1266, in _load_model_class
#     return cls.model_class().load(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/models.py", line 431, in load
#     model.fit(data_generator, verbose=False)
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/temp_keras_modules.py", line 388, in fit
#     tmp_logs = self.train_function(iterator)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/def_function.py", line 915, in __call__
#     result = self._call(*args, **kwds)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/def_function.py", line 963, in _call
#     self._initialize(args, kwds, add_initializers_to=initializers)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/def_function.py", line 785, in _initialize
#     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 2983, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 3292, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 3130, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py", line 1161, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/def_function.py", line 677, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py", line 1136, in autograph_handler
#     return autograph.converted_call(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 439, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/__autograph_generated_fileeouiw5bn.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 377, in converted_call
#     return _call_unconverted(f, args, kwargs, options)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in _call_unconverted
#     return f(*args)
#   File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1010, in step_function
#     outputs = model.distribute_strategy.run(run_step, args=(data,))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py", line 1312, in run
#     return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py", line 2888, in call_for_each_replica
#     return self._call_for_each_replica(fn, args, kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py", line 3689, in _call_for_each_replica
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 689, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 377, in converted_call
#     return _call_unconverted(f, args, kwargs, options)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 458, in _call_unconverted
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras/engine/training.py", line 1000, in run_step
#     outputs = model.train_step(data)
#   File "/usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/models.py", line 151, in train_step
#     prediction_loss = self.batch_loss(batch_in)
#   File "/usr/local/lib/python3.10/dist-packages/rasa/nlu/classifiers/diet_classifier.py", line 1643, in batch_loss
#     losses += self._batch_loss_entities(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/nlu/classifiers/diet_classifier.py", line 1705, in _batch_loss_entities
#     loss, f1, _logits = self._calculate_entity_loss(
#   File "/usr/local/lib/python3.10/dist-packages/rasa/utils/tensorflow/models.py", line 885, in _calculate_entity_loss
#     pred_ids, _ = self._tf_layers[f"crf.{tag_name}"](logits, sequence_lengths)
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras/engine/base_layer.py", line 1096, in __call__
#     outputs = call_fn(inputs, *args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py", line 92, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 689, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 439, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/__autograph_generated_filepzfkbmj9.py", line 23, in tf__call
#     (predicted_ids, scores, _) = ag__.converted_call(ag__.ld(rasa).utils.tensorflow.crf.crf_decode, (ag__.ld(logits), ag__.ld(self).transition_params, ag__.ld(sequence_lengths)), None, fscope)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 441, in converted_call
#     result = converted_f(*effective_args)
#   File "/tmp/__autograph_generated_filenqm0pnya.py", line 122, in tf__crf_decode
#     ag__.if_stmt(ag__.ld(potentials).shape[1] is not None, if_body_1, else_body_1, get_state_1, set_state_1, ('do_return', 'retval_'), 2)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 1321, in if_stmt
#     _py_if_stmt(cond, body, orelse)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/operators/control_flow.py", line 1374, in _py_if_stmt
#     return body() if cond else orelse()
#   File "/tmp/__autograph_generated_filenqm0pnya.py", line 118, in else_body_1
#     retval_ = ag__.converted_call(ag__.ld(tf).cond, (ag__.converted_call(ag__.ld(tf).equal, (ag__.converted_call(ag__.ld(tf).shape, (ag__.ld(potentials),), None, fscope)[1], 1), None, fscope), ag__.ld(_single_seq_fn), ag__.ld(_multi_seq_fn)), None, fscope)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 331, in converted_call
#     return _call_unconverted(f, args, kwargs, options, False)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py", line 459, in _call_unconverted
#     return f(*args)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py", line 1082, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/control_flow_ops.py", line 1452, in cond_for_tf_v2
#     return cond(pred, true_fn=true_fn, false_fn=false_fn, strict=True, name=name)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py", line 1082, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py", line 548, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/control_flow_ops.py", line 1265, in cond
#     return cond_v2.cond_v2(pred, true_fn, false_fn, name)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond_v2.py", line 95, in cond_v2
#     return _build_cond(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond_v2.py", line 295, in _build_cond
#     tensors = util.run_as_function_for_tape_gradients(_make_op, cond_inputs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/control_flow_util_v2.py", line 370, in run_as_function_for_tape_gradients
#     results = function.defun_with_attributes(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 2956, in __call__
#     return graph_function._call_flat(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 1859, in _call_flat
#     forward_function, args_with_tangents = forward_backward.forward()
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 1399, in forward
#     forward_function = self._functions.forward(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 1131, in forward
#     self._forward_and_backward_functions(inference_args, input_tangents))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 1355, in _forward_and_backward_functions
#     self._build_functions_for_outputs(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 851, in _build_functions_for_outputs
#     gradients_wrt_inputs = gradients_util._GradientsHelper(  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 679, in _GradientsHelper
#     in_grads = _MaybeCompile(grad_scope, op, func_call,
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 328, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 680, in <lambda>
#     lambda: grad_fn(op, *out_grads))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond_v2.py", line 122, in _IfGrad
#     false_grad_graph = _create_grad_func(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond_v2.py", line 389, in _create_grad_func
#     return func_graph_module.func_graph_from_py_func(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py", line 1161, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond_v2.py", line 391, in <lambda>
#     lambda: _grad_fn(func_graph, grads), [], {},
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond_v2.py", line 380, in _grad_fn
#     result = gradients_util._GradientsHelper(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 679, in _GradientsHelper
#     in_grads = _MaybeCompile(grad_scope, op, func_call,
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 328, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 680, in <lambda>
#     lambda: grad_fn(op, *out_grads))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 707, in _rewrite_forward_and_call_backward
#     return backwards_function._call_flat(  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 1859, in _call_flat
#     forward_function, args_with_tangents = forward_backward.forward()
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 1399, in forward
#     forward_function = self._functions.forward(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 1131, in forward
#     self._forward_and_backward_functions(inference_args, input_tangents))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 1360, in _forward_and_backward_functions
#     self._build_functions_for_outputs(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/function.py", line 851, in _build_functions_for_outputs
#     gradients_wrt_inputs = gradients_util._GradientsHelper(  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 679, in _GradientsHelper
#     in_grads = _MaybeCompile(grad_scope, op, func_call,
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 328, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 680, in <lambda>
#     lambda: grad_fn(op, *out_grads))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_v2.py", line 384, in _WhileGrad
#     body_grad_graph, args = _create_grad_func(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_v2.py", line 686, in _create_grad_func
#     grad_func_graph = func_graph_module.func_graph_from_py_func(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py", line 1161, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_v2.py", line 688, in <lambda>
#     lambda *args: _grad_fn(ys, xs, args, body_graph),
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_v2.py", line 744, in _grad_fn
#     grad_outs = gradients_util._GradientsHelper(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 679, in _GradientsHelper
#     in_grads = _MaybeCompile(grad_scope, op, func_call,
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 328, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gradients_util.py", line 680, in <lambda>
#     lambda: grad_fn(op, *out_grads))
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/list_ops.py", line 308, in _TensorListSetItemGrad
#     element_grad = tensor_list_get_item(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/list_ops.py", line 105, in tensor_list_get_item
#     return gen_list_ops.tensor_list_get_item(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_list_ops.py", line 562, in tensor_list_get_item
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/op_def_library.py", line 740, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/while_v2.py", line 1035, in _create_op_internal
#     return super(_WhileBodyGradFuncGraph, self)._create_op_internal(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py", line 693, in _create_op_internal
#     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py", line 3776, in _create_op_internal
#     ret = Operation(
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py", line 2171, in __init__
#     self._c_op = _create_c_op(self._graph, node_def, inputs,
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
# KeyboardInterrupt
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Reshape:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_grad/gradients/cond/GatherV2_grad/Cast:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradients/cond_1_grad/Identity_1:0", shape=(None,), dtype=int64), values=Tensor("gradients/cond_1_grad/Identity:0", shape=(None,), dtype=float32), dense_shape=Tensor("gradients/cond_1_grad/Identity_2:0", shape=(1,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# WARNING:rasa.shared.utils.common:The UnexpecTED Intent Policy is currently experimental and might change or be removed in the future 🔬 Please share your feedback on it in the forum (https://forum.rasa.com) to help us make this feature ready for production.
# Your bot is ready to talk! Type your messages here or send '/stop'.
# Hey! How are you?
# Dear None, your account None has a balance of Rs. 1000.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 2
#       1 endpoints = None
# ----> 2 chat(model_path.model, endpoints)
#
# File /usr/local/lib/python3.10/dist-packages/rasa/jupyter.py:45, in chat(model_path, endpoints, agent)
#      43 print("Your bot is ready to talk! Type your messages here or send '/stop'.")
#      44 while True:
# ---> 45     message = input()
#      46     if message == "/stop":
#      47         break
#
# File /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py:851, in Kernel.raw_input(self, prompt)
#     847 if not self._allow_stdin:
#     848     raise StdinNotImplementedError(
#     849         "raw_input was called, but this frontend does not support input requests."
#     850     )
# --> 851 return self._input_request(str(prompt),
#     852     self._parent_ident,
#     853     self._parent_header,
#     854     password=False,
#     855 )
#
# File /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py:895, in Kernel._input_request(self, prompt, ident, parent, password)
#     892             break
#     893 except KeyboardInterrupt:
#     894     # re-raise KeyboardInterrupt, to truncate traceback
# --> 895     raise KeyboardInterrupt("Interrupted by user") from None
#     896 except Exception as e:
#     897     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# !zip -r /content/rasa_3x.zip /content/rasa_3x
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   adding: content/rasa_3x/ (stored 0%)
#   adding: content/rasa_3x/endpoints.yml (deflated 58%)
#   adding: content/rasa_3x/actions/ (stored 0%)
#   adding: content/rasa_3x/actions/__init__.py (stored 0%)
#   adding: content/rasa_3x/actions/actions.py (deflated 55%)
#   adding: content/rasa_3x/actions/__pycache__/ (stored 0%)
#   adding: content/rasa_3x/actions/__pycache__/__init__.cpython-310.pyc (deflated 20%)
#   adding: content/rasa_3x/actions/__pycache__/actions.cpython-310.pyc (deflated 20%)
#   adding: content/rasa_3x/tests/ (stored 0%)
#   adding: content/rasa_3x/tests/test_stories.yml (deflated 77%)
#   adding: content/rasa_3x/domain.yml (deflated 65%)
#   adding: content/rasa_3x/config.yml (deflated 65%)
#   adding: content/rasa_3x/data/ (stored 0%)
#   adding: content/rasa_3x/data/stories.yml (deflated 78%)
#   adding: content/rasa_3x/data/rules.yml (deflated 45%)
#   adding: content/rasa_3x/data/nlu.yml (deflated 65%)
#   adding: content/rasa_3x/models/ (stored 0%)
#   adding: content/rasa_3x/models/20230602-082720-uniform-clutter.tar.gz (deflated 0%)
#   adding: content/rasa_3x/models/20230602-085446-asphalt-offset.tar.gz (deflated 0%)
#   adding: content/rasa_3x/models/20230602-084450-critical-quasar.tar.gz (deflated 0%)
#   adding: content/rasa_3x/models/20230602-064810-swarm-seasoning.tar.gz (deflated 0%)
#   adding: content/rasa_3x/models/20230602-060913-rowdy-swift.tar.gz (deflated 0%)
#   adding: content/rasa_3x/models/20230602-063850-quantum-relaxation.tar.gz (deflated 0%)
#   adding: content/rasa_3x/models/20230602-020057-coal-column.tar.gz (deflated 0%)
#   adding: content/rasa_3x/models/20230602-090639-jovial-zinc.tar.gz (deflated 0%)
#   adding: content/rasa_3x/models/20230602-063217-tranquil-scarfing.tar.gz (deflated 0%)
#   adding: content/rasa_3x/.rasa/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpgocudqgv/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpgocudqgv/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpgocudqgv/vocabularies.pkl (deflated 57%)
#   adding: content/rasa_3x/.rasa/cache/tmp8av1wlzg/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp8av1wlzg/memorized_turns.json (deflated 42%)
#   adding: content/rasa_3x/.rasa/cache/tmp8av1wlzg/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmpd4vju_yd/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmphqdpvbqp/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpckzkt8z4/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpckzkt8z4/feature_to_idx_dict.pkl (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ted_policy.label_data.pkl (deflated 87%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ted_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ted_policy.tf_model.data-00000-of-00001 (deflated 29%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ted_policy.meta.pkl (deflated 50%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ted_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/checkpoint (deflated 42%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ted_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/featurizer.json (deflated 59%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ted_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmppov6a3tg/ted_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ted_policy.label_data.pkl (deflated 87%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ted_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ted_policy.tf_model.data-00000-of-00001 (deflated 29%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ted_policy.meta.pkl (deflated 50%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ted_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/checkpoint (deflated 42%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ted_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/featurizer.json (deflated 59%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ted_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmps0f0gfef/ted_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmppoz28909/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmppoz28909/rule_only_data.json (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmppoz28909/rule_policy.json (deflated 81%)
#   adding: content/rasa_3x/.rasa/cache/tmppoz28909/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmpifta2toc/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpifta2toc/patterns.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpgxbzbp60/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpgxbzbp60/patterns.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp43twqmx0/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp7nzwm1ms/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp7nzwm1ms/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp7nzwm1ms/vocabularies.pkl (deflated 58%)
#   adding: content/rasa_3x/.rasa/cache/tmp478xxt29/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp478xxt29/memorized_turns.json (deflated 42%)
#   adding: content/rasa_3x/.rasa/cache/tmp478xxt29/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmpldsnjhs1/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpldsnjhs1/feature_to_idx_dict.pkl (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/cache.db (deflated 82%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.label_quantiles.pkl (deflated 72%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.tf_model.data-00000-of-00001 (deflated 44%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/checkpoint (deflated 46%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/featurizer.json (deflated 59%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.meta.pkl (deflated 45%)
#   adding: content/rasa_3x/.rasa/cache/tmpjct_ccjs/unexpected_intent_policy.label_data.pkl (deflated 79%)
#   adding: content/rasa_3x/.rasa/cache/tmp44bnm_g0/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp44bnm_g0/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp44bnm_g0/vocabularies.pkl (deflated 63%)
#   adding: content/rasa_3x/.rasa/cache/tmp0xkji88e/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpuqm8eqsf/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpuqm8eqsf/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpuqm8eqsf/vocabularies.pkl (deflated 63%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/DIETClassifier.tf_model.index (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/DIETClassifier.tf_model.data-00000-of-00001 (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/DIETClassifier.index_label_id_mapping.json (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/checkpoint (deflated 43%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/DIETClassifier.data_example.pkl (deflated 73%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/DIETClassifier.label_data.pkl (deflated 78%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/DIETClassifier.sparse_feature_sizes.pkl (deflated 21%)
#   adding: content/rasa_3x/.rasa/cache/tmpf_orphxs/DIETClassifier.entity_tag_specs.json (deflated 67%)
#   adding: content/rasa_3x/.rasa/cache/tmprxggpiee/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmprxggpiee/patterns.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmptqx1z3tr/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmptqx1z3tr/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmptqx1z3tr/vocabularies.pkl (deflated 63%)
#   adding: content/rasa_3x/.rasa/cache/tmp7me9igwn/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/DIETClassifier.tf_model.index (deflated 78%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/DIETClassifier.tf_model.data-00000-of-00001 (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/DIETClassifier.index_label_id_mapping.json (deflated 28%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/checkpoint (deflated 43%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/DIETClassifier.data_example.pkl (deflated 64%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/DIETClassifier.label_data.pkl (deflated 70%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/DIETClassifier.sparse_feature_sizes.pkl (deflated 21%)
#   adding: content/rasa_3x/.rasa/cache/tmpi5e72cbu/DIETClassifier.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpfm8n7wud/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpujo90yty/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpujo90yty/patterns.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpm4dn07qz/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpvtu2jts3/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp_yys0w53/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp_yys0w53/feature_to_idx_dict.pkl (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmpe22b_svn/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpe22b_svn/rule_only_data.json (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmpe22b_svn/rule_policy.json (deflated 84%)
#   adding: content/rasa_3x/.rasa/cache/tmpe22b_svn/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.label_quantiles.pkl (deflated 72%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.tf_model.data-00000-of-00001 (deflated 44%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/checkpoint (deflated 46%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/featurizer.json (deflated 59%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.meta.pkl (deflated 45%)
#   adding: content/rasa_3x/.rasa/cache/tmp4xa_j3r3/unexpected_intent_policy.label_data.pkl (deflated 79%)
#   adding: content/rasa_3x/.rasa/cache/tmp6e0x43fy/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp6e0x43fy/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp6e0x43fy/vocabularies.pkl (deflated 58%)
#   adding: content/rasa_3x/.rasa/cache/tmpa6qu4qnc/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpa6qu4qnc/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpa6qu4qnc/vocabularies.pkl (deflated 63%)
#   adding: content/rasa_3x/.rasa/cache/tmpjeitgyde/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpjeitgyde/memorized_turns.json (deflated 42%)
#   adding: content/rasa_3x/.rasa/cache/tmpjeitgyde/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmpmonbkzvj/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ted_policy.label_data.pkl (deflated 82%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ted_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ted_policy.tf_model.data-00000-of-00001 (deflated 29%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ted_policy.meta.pkl (deflated 50%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ted_policy.tf_model.index (deflated 75%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/checkpoint (deflated 42%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ted_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/featurizer.json (deflated 57%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ted_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmpujh_yasp/ted_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp0dm2lnmd/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp0dm2lnmd/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp0dm2lnmd/vocabularies.pkl (deflated 63%)
#   adding: content/rasa_3x/.rasa/cache/tmp2njxym2p/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.label_quantiles.pkl (deflated 72%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.tf_model.data-00000-of-00001 (deflated 44%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/checkpoint (deflated 46%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/featurizer.json (deflated 58%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.meta.pkl (deflated 45%)
#   adding: content/rasa_3x/.rasa/cache/tmp1t94bbik/unexpected_intent_policy.label_data.pkl (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ted_policy.label_data.pkl (deflated 84%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ted_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ted_policy.tf_model.data-00000-of-00001 (deflated 29%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ted_policy.meta.pkl (deflated 50%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ted_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/checkpoint (deflated 42%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ted_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/featurizer.json (deflated 58%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ted_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmpnjr3ybsm/ted_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp6xqvl79a/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/DIETClassifier.tf_model.index (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/DIETClassifier.tf_model.data-00000-of-00001 (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/DIETClassifier.index_label_id_mapping.json (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/checkpoint (deflated 43%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/DIETClassifier.data_example.pkl (deflated 73%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/DIETClassifier.label_data.pkl (deflated 78%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/DIETClassifier.sparse_feature_sizes.pkl (deflated 21%)
#   adding: content/rasa_3x/.rasa/cache/tmpwmczq4fx/DIETClassifier.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpbcikcaox/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpbcikcaox/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpbcikcaox/vocabularies.pkl (deflated 58%)
#   adding: content/rasa_3x/.rasa/cache/tmpr5hc8fjf/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpr5hc8fjf/feature_to_idx_dict.pkl (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmpqltmzu1t/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp79ulzxwy/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp79ulzxwy/memorized_turns.json (deflated 47%)
#   adding: content/rasa_3x/.rasa/cache/tmp79ulzxwy/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmp_c1e2mia/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp5vjlqbqo/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp5vjlqbqo/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp5vjlqbqo/vocabularies.pkl (deflated 63%)
#   adding: content/rasa_3x/.rasa/cache/tmpdem66ys1/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpsz_90bnq/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpsz_90bnq/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpsz_90bnq/vocabularies.pkl (deflated 57%)
#   adding: content/rasa_3x/.rasa/cache/tmpyvf4hvtb/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpyvf4hvtb/patterns.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/DIETClassifier.tf_model.index (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/DIETClassifier.tf_model.data-00000-of-00001 (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/DIETClassifier.index_label_id_mapping.json (deflated 34%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/checkpoint (deflated 43%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/DIETClassifier.data_example.pkl (deflated 80%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/DIETClassifier.label_data.pkl (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/DIETClassifier.sparse_feature_sizes.pkl (deflated 21%)
#   adding: content/rasa_3x/.rasa/cache/tmpjho06sk0/DIETClassifier.entity_tag_specs.json (deflated 55%)
#   adding: content/rasa_3x/.rasa/cache/tmp_3e7cdf0/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmptm59k_p5/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmptm59k_p5/feature_to_idx_dict.pkl (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmp4oaby13k/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp4oaby13k/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp4oaby13k/vocabularies.pkl (deflated 63%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.label_quantiles.pkl (deflated 80%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.tf_model.data-00000-of-00001 (deflated 44%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/checkpoint (deflated 46%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/featurizer.json (deflated 57%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.meta.pkl (deflated 45%)
#   adding: content/rasa_3x/.rasa/cache/tmpimquj3y8/unexpected_intent_policy.label_data.pkl (deflated 69%)
#   adding: content/rasa_3x/.rasa/cache/tmpwkiuncnc/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpwkiuncnc/patterns.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/DIETClassifier.tf_model.index (deflated 78%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/DIETClassifier.tf_model.data-00000-of-00001 (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/DIETClassifier.index_label_id_mapping.json (deflated 34%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/checkpoint (deflated 43%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/DIETClassifier.data_example.pkl (deflated 79%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/DIETClassifier.label_data.pkl (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/DIETClassifier.sparse_feature_sizes.pkl (deflated 21%)
#   adding: content/rasa_3x/.rasa/cache/tmpzue32ikc/DIETClassifier.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.label_quantiles.pkl (deflated 73%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.tf_model.data-00000-of-00001 (deflated 44%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/checkpoint (deflated 46%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/featurizer.json (deflated 59%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.meta.pkl (deflated 45%)
#   adding: content/rasa_3x/.rasa/cache/tmpkoueu523/unexpected_intent_policy.label_data.pkl (deflated 79%)
#   adding: content/rasa_3x/.rasa/cache/tmpe5eflobw/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpe5eflobw/rule_only_data.json (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmpe5eflobw/rule_policy.json (deflated 84%)
#   adding: content/rasa_3x/.rasa/cache/tmpe5eflobw/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lwg6afp/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lwg6afp/patterns.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpugafpa47/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/DIETClassifier.tf_model.index (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/DIETClassifier.tf_model.data-00000-of-00001 (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/DIETClassifier.index_label_id_mapping.json (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/checkpoint (deflated 43%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/DIETClassifier.data_example.pkl (deflated 73%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/DIETClassifier.label_data.pkl (deflated 78%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/DIETClassifier.sparse_feature_sizes.pkl (deflated 21%)
#   adding: content/rasa_3x/.rasa/cache/tmp7lpt03s2/DIETClassifier.entity_tag_specs.json (deflated 67%)
#   adding: content/rasa_3x/.rasa/cache/tmp96efl5in/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp12lnnayg/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp12lnnayg/rule_only_data.json (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmp12lnnayg/rule_policy.json (deflated 84%)
#   adding: content/rasa_3x/.rasa/cache/tmp12lnnayg/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmpi1u98et4/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpi1u98et4/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpi1u98et4/vocabularies.pkl (deflated 58%)
#   adding: content/rasa_3x/.rasa/cache/tmpp_2rezcx/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpp_2rezcx/oov_words.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpp_2rezcx/vocabularies.pkl (deflated 58%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/DIETClassifier.tf_model.index (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/DIETClassifier.tf_model.data-00000-of-00001 (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/DIETClassifier.index_label_id_mapping.json (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/checkpoint (deflated 43%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/DIETClassifier.data_example.pkl (deflated 73%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/DIETClassifier.label_data.pkl (deflated 78%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/DIETClassifier.sparse_feature_sizes.pkl (deflated 21%)
#   adding: content/rasa_3x/.rasa/cache/tmpnvblf13s/DIETClassifier.entity_tag_specs.json (deflated 67%)
#   adding: content/rasa_3x/.rasa/cache/tmp5vsao6vz/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmp5vsao6vz/rule_only_data.json (deflated 27%)
#   adding: content/rasa_3x/.rasa/cache/tmp5vsao6vz/rule_policy.json (deflated 84%)
#   adding: content/rasa_3x/.rasa/cache/tmp5vsao6vz/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmps5zjc8_d/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpxcigj5yx/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpxcigj5yx/memorized_turns.json (deflated 52%)
#   adding: content/rasa_3x/.rasa/cache/tmpxcigj5yx/featurizer.json (deflated 30%)
#   adding: content/rasa_3x/.rasa/cache/tmpmhv6frjs/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpmhv6frjs/feature_to_idx_dict.pkl (deflated 77%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ted_policy.label_data.pkl (deflated 87%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ted_policy.entity_tag_specs.json (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ted_policy.tf_model.data-00000-of-00001 (deflated 29%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ted_policy.meta.pkl (deflated 50%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ted_policy.tf_model.index (deflated 74%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/checkpoint (deflated 42%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ted_policy.data_example.pkl (deflated 53%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/featurizer.json (deflated 59%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ted_policy.fake_features.pkl (deflated 39%)
#   adding: content/rasa_3x/.rasa/cache/tmppjr4w6t8/ted_policy.priority.pkl (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpttrze17j/ (stored 0%)
#   adding: content/rasa_3x/.rasa/cache/tmpttrze17j/feature_to_idx_dict.pkl (deflated 77%)
#   adding: content/rasa_3x/credentials.yml (deflated 50%)

# %%
from google.colab import files
files.download('/content/rasa_3x.zip')
